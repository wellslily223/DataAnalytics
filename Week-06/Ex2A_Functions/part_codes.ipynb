# %% [markdown]
# # Exercise 2.A Using built-in functions
# ## Lab 2. Parsing strings – part codes

# %%
information = 'ACME:123-L'
def parse_and_display(information):
            supplier_code = information[:4]
            product_code = information[5:7]
            size = information[9:]
            print(f'{supplier_code}:{product_code}-{size}')
            print(f"Supplier code: {supplier_code}")
            print(f"Product Code: {product_code}")
            print(f"Size: {size}")

# %%
parse_and_display(information)
# Out:
# ACME:12-L
# Supplier code: ACME
# Product Code: 12
# Size: L

# %%
def get_supplier_code(supplier_code):
    return code1.split(":")[0]

# %%
def get_product_code(product_code):
    product_code_size = code1.split(":")[1]
    return product_code_size.split("-")[0]

# %%
def get_size(size):
    return code1.split("-")[1]
    return code1.split(":")[1]

# %%
code1 = information
supplier_code2 = get_supplier_code(code1)
product_code2 = get_product_code(code1)
size2 = get_size(code1)

print(f"For {information}, the supplier is {supplier_code2}. Part number {product_code2} is available in size {size2}.")
# Out:
# For ACME:123-L, the supplier is ACME. Part number 123 is available in size L.
